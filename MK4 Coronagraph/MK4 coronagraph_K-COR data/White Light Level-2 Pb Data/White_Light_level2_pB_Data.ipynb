# %% [markdown]
# # FITSファイルを見るためのPythonコード

# %% [markdown]
# tarアーカイブでダウンロードした場合，解凍する作業が必要．

# %%
import tarfile
import gzip
import glob
from matplotlib.animation import FuncAnimation
from astropy.io import fits
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.patches import Circle
import os
from matplotlib.colors import LogNorm
import numpy as np

# %%
# 圧縮ファイルのパスと出力フォルダ
tar_path = '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613.kcor_pb.fits.tar'
output_folder = '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data'

# %% [markdown]
# ## ファイルの解凍

# %%
def extract_fits_files(tar_path, extract_folder):
    """FITSファイルを圧縮ファイルから解凍し、展開する."""
    if not os.path.exists(extract_folder):
        os.makedirs(extract_folder)

    with tarfile.open(tar_path, 'r') as tar:
        tar.extractall(path=extract_folder)
        print(f"Files extracted to: {extract_folder}")

    gz_files = []
    for root, dirs, files in os.walk(extract_folder):
        for file in files:
            if file.endswith('.fts.gz'):
                gz_files.append(os.path.join(root, file))

    fts_files = []
    for gz_file in gz_files:
        fts_file = gz_file[:-3]  # .gzを取り除く
        with gzip.open(gz_file, 'rb') as gz:
            with open(fts_file, 'wb') as fts:
                fts.write(gz.read())
        fts_files.append(fts_file)

    print("Decompressed FTS files:", fts_files)
    return fts_files

# %%
# 1. FITSファイルの解凍
fts_files = extract_fits_files(tar_path, output_folder)
# Out:
# Files extracted to: /home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data
# Decompressed FTS files: ['/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_030530_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_033450_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_035217_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_031104_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_034713_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_032257_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_030158_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_035619_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_035046_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_030545_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_030027_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_032010_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_033117_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_035403_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_035821_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_031753_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_031235_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_031824_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_032931_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_033722_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_035433_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_034210_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_032055_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_034527_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_031336_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_030445_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_030933_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_030847_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_031955_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_030747_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_033837_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_031220_kcor_l2.fts', '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_034542_kcor_l2.fts', '/home/kinno-70 ...

# %% [markdown]
# ## FITSデータをプロット

# %%
def read_fits_file(fits_path):
    """FITSファイルを読み込み、データとヘッダーを返す."""
    with fits.open(fits_path) as hdul:
        data = hdul[0].data
        header = hdul[0].header
    return data, header

def calculate_statistics(data, exclude_zeros=True):
    """データの統計情報を計算."""
    if exclude_zeros:
        data = data[data > 0]  # ゼロ以下を除外
    return {
        "min": np.min(data),
        "max": np.max(data),
        "mean": np.mean(data),
        "median": np.median(data),
        "std": np.std(data),
    }


def visualize_fits_data(data, header, statistics):
    """FITSデータを可視化し、X, Y の単位を太陽半径に変換."""
    # 太陽中心座標と太陽半径（ピクセル単位）
    solar_x = header.get('CRPIX1', data.shape[1] // 2) - 1  # FITS index starts at 1
    solar_y = header.get('CRPIX2', data.shape[0] // 2) - 1
    solar_radius = header.get('R_SUN', 0)

    # ピクセルスケールを太陽半径に変換
    if solar_radius > 0:
        pixel_to_rsun = 1 / solar_radius  # 1ピクセルあたりの太陽半径
    else:
        raise ValueError("Invalid solar radius in header.")

    # データの統計情報
    data_mean = statistics["mean"]
    data_std = statistics["std"]

    # カラーバーの範囲を設定
    custom_vmin = data_mean - 2 * data_std
    custom_vmax = data_mean + 5 * data_std

    # プロット
    plt.figure(figsize=(8, 8))
    ax = plt.gca()

    # X, Y 軸の範囲を太陽半径に変換
    extent = [
        -solar_x * pixel_to_rsun, (data.shape[1] - solar_x) * pixel_to_rsun,
        -solar_y * pixel_to_rsun, (data.shape[0] - solar_y) * pixel_to_rsun
    ]

    im = ax.imshow(data, cmap='gray', origin='lower', vmin=custom_vmin, vmax=custom_vmax, extent=extent)

    # 太陽中心を通る円を描画
    if solar_radius > 0:
        circle = Circle((0, 0), solar_radius * pixel_to_rsun, color='red', fill=False, lw=1.5, label="Solar Disk")
        ax.add_patch(circle)

    # 特定の座標を通る円の描画
    custom_radius = np.sqrt((0 - solar_x) ** 2 + (solar_y - solar_y) ** 2) * pixel_to_rsun
    circle = Circle((0, 0), custom_radius, color='white', fill=False, linestyle='--', lw=1.0, label="Custom Radius")
    ax.add_patch(circle)
    

    # 太陽中心の赤い点を描画
    ax.scatter(0, 0, color='red', s=50, label="Solar Center")
    
        # グリッドの追加 (0.5 Rsごと)
    grid_spacing = 0.5  # グリッド間隔
    x_min, x_max = int(extent[0] // grid_spacing) * grid_spacing, int(extent[1] // grid_spacing) * grid_spacing
    y_min, y_max = int(extent[2] // grid_spacing) * grid_spacing, int(extent[3] // grid_spacing) * grid_spacing
    ax.set_xticks(np.arange(x_min+grid_spacing, x_max + grid_spacing, grid_spacing))
    ax.set_yticks(np.arange(y_min+grid_spacing, y_max + grid_spacing, grid_spacing))
    ax.grid(color='white', linestyle='--', linewidth=0.1)
    

    # カラーバー設定
    # divider = make_axes_locatable(ax)
    # cax = divider.append_axes("right", size="3%", pad=0.1)
    # plt.colorbar(im, cax=cax, label="Brightness (B/Bsun)")

    # タイトルとラベル
    ax.set_title("White Light Level-2 Pb Data", fontsize=20)
    ax.set_xlabel("X [Solar Radius $R_\\odot$]", fontsize=16)
    ax.set_ylabel("Y [Solar Radius $R_\\odot$]", fontsize=16)

    # 凡例表示
    # ax.legend()
    plt.show()

# %%
# 2. 最初のFITSファイルを読み込む
if fts_files:
    data, header = read_fits_file(fts_files[0])

    # 3. 統計情報の計算
    stats = calculate_statistics(data)
    print(f"Statistics:", stats)
    print("fts_files[0]:", fts_files[0])

    # 4. 可視化
    visualize_fits_data(data, header, stats)
# Out:
# Statistics: {'min': np.float32(2.3298255e-16), 'max': np.float32(9.2102965e-07), 'mean': np.float32(5.7811164e-08), 'median': np.float32(1.26566935e-08), 'std': np.float32(1.0788578e-07)}
# fts_files[0]: /home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_030530_kcor_l2.fts

# %% [markdown]
# ## Test

# %%
def draw_frame(data, header, ax):
    """単一フレームを描画."""
    # 太陽中心と半径
    solar_x = header.get('CRPIX1', data.shape[1] // 2) - 1
    solar_y = header.get('CRPIX2', data.shape[0] // 2) - 1
    solar_radius = header.get('R_SUN', 0)

    # ピクセルスケールを太陽半径に変換
    pixel_to_rsun = 1 / solar_radius if solar_radius > 0 else 1

    # データの統計情報を計算
    stats = calculate_statistics(data)
    data_mean, data_std = stats["mean"], stats["std"]
    custom_vmin = 0
    custom_vmax = data_mean + 5 * data_std


    # 軸の設定
    extent = [
        -solar_x * pixel_to_rsun, (data.shape[1] - solar_x) * pixel_to_rsun,
        -solar_y * pixel_to_rsun, (data.shape[0] - solar_y) * pixel_to_rsun
    ]
    ax.clear()
    im = ax.imshow(data, cmap='gray', origin='lower', vmin=custom_vmin, vmax=custom_vmax, extent=extent)

    # 太陽中心と円を描画
    ax.scatter(0, 0, color='red', s=50, label="Solar Center")
    if solar_radius > 0:
        circle = Circle((0, 0), solar_radius * pixel_to_rsun, color='red', fill=False, lw=1.5, label="Solar Disk")
        ax.add_patch(circle)
        
        # 特定の座標を通る円の描画
    custom_radius = np.sqrt((0 - solar_x) ** 2 + (solar_y - solar_y) ** 2) * pixel_to_rsun
    circle = Circle((0, 0), custom_radius, color='white', fill=False, linestyle='--', lw=1.0, label="Custom Radius")
    ax.add_patch(circle)

    # グリッドの描画 (0.5 Rsごと)
    grid_spacing = 0.5
    x_min, x_max = int(extent[0] // grid_spacing) * grid_spacing, int(extent[1] // grid_spacing) * grid_spacing
    y_min, y_max = int(extent[2] // grid_spacing) * grid_spacing, int(extent[3] // grid_spacing) * grid_spacing
    ax.set_xticks(np.arange(x_min+grid_spacing, x_max + grid_spacing, grid_spacing))
    ax.set_yticks(np.arange(y_min+grid_spacing, y_max + grid_spacing, grid_spacing))
    ax.grid(color='white', linestyle='--', linewidth=0.1)

    # タイトルと軸ラベル
    file_name = os.path.basename(header.get('FILENAME', ''))
    date_obs = header.get('DATE-OBS', 'Unknown Time')  # 観測時間を取得
    ax.set_title(f"Time: {date_obs}", fontsize=12)  # タイトルに観測時間を表示
    ax.set_xlabel("X [Solar Radius $R_\\odot$]", fontsize=10)
    ax.set_ylabel("Y [Solar Radius $R_\\odot$]", fontsize=10)

    return im

# フォルダー内のFITSファイルを取得
folder_path = "/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data"
fts_files = sorted(glob.glob(os.path.join(folder_path, "*.fts")))

# アニメーション作成
fig, ax = plt.subplots(figsize=(8, 8))

def update_frame(i):
    """アニメーションフレームを更新."""
    data, header = read_fits_file(fts_files[i])
    return [draw_frame(data, header, ax)]

ani = FuncAnimation(
    fig,
    update_frame,
    frames=len(fts_files),
    interval=15000 / len(fts_files),  # 15秒間隔に調整
)

# 動画の保存
output_path = "/home/kinno-7010/Document/Iwai2020event/kcor_animation.mp4"
ani.save(output_path, writer='ffmpeg', fps=10)

print(f"Animation saved to {output_path}")
# Out:
# Animation saved to /home/kinno-7010/Document/Iwai2020event/kcor_animation.mp4

# %%
def read_fits_file(fits_path):
    """FITSファイルを読み込み、データとヘッダーを返す."""
    with fits.open(fits_path) as hdul:
        data = hdul[0].data
        header = hdul[0].header
    return data, header

def calculate_statistics(data, exclude_zeros=False):
    """データの統計情報を計算."""
    if exclude_zeros:
        data = data[data > 0]  # ゼロ以下を除外
    return {
        "min": np.min(data),
        "max": np.max(data),
        "mean": np.mean(data),
        "median": np.median(data),
        "std": np.std(data),
    }

def draw_frame(data, header, ax):
    """単一フレームを描画."""
    # 太陽中心と半径
    solar_x = header.get('CRPIX1', data.shape[1] // 2) - 1
    solar_y = header.get('CRPIX2', data.shape[0] // 2) - 1
    solar_radius = header.get('R_SUN', 0)

    # ピクセルスケールを太陽半径に変換
    pixel_to_rsun = 1 / solar_radius if solar_radius > 0 else 1

    # データの統計情報を計算
    stats = calculate_statistics(data)
    data_min, data_max, data_mean,data_median, data_std = stats["min"], stats["max"], stats["mean"], stats["median"], stats["std"]
    custom_vmin = -8e-9
    custom_vmax = 9e-7
    # print("data_min:", data_min)
    # print("data_max:", data_max)
    # print("data_mean:", data_mean)
    # print("data_median:", data_median)
    # print("data_std:", data_std)
    

    # 軸の設定
    extent = [
        -solar_x * pixel_to_rsun, (data.shape[1] - solar_x) * pixel_to_rsun,
        -solar_y * pixel_to_rsun, (data.shape[0] - solar_y) * pixel_to_rsun
    ]
    ax.clear()
    im = ax.imshow(data, cmap='gray', origin='lower', vmin=custom_vmin, vmax=custom_vmax, extent=extent)

    # 太陽中心と円を描画
    ax.scatter(0, 0, color='red', s=50, label="Solar Center")
    if solar_radius > 0:
        circle = Circle((0, 0), solar_radius * pixel_to_rsun, color='red', fill=False, lw=1.5, label="Solar Disk")
        ax.add_patch(circle)
        
        # 特定の座標を通る円の描画
    custom_radius = np.sqrt((0 - solar_x) ** 2 + (solar_y - solar_y) ** 2) * pixel_to_rsun
    circle = Circle((0, 0), custom_radius, color='white', fill=False, linestyle='--', lw=1.0, label="Custom Radius")
    ax.add_patch(circle)

    # グリッドの描画 (0.5 Rsごと)
    grid_spacing = 0.5
    x_min, x_max = int(extent[0] // grid_spacing) * grid_spacing, int(extent[1] // grid_spacing) * grid_spacing
    y_min, y_max = int(extent[2] // grid_spacing) * grid_spacing, int(extent[3] // grid_spacing) * grid_spacing
    ax.set_xticks(np.arange(x_min+grid_spacing, x_max + grid_spacing, grid_spacing))
    ax.set_yticks(np.arange(y_min+grid_spacing, y_max + grid_spacing, grid_spacing))
    ax.grid(color='white', linestyle='--', linewidth=0.1)

    # タイトルと軸ラベル
    file_name = os.path.basename(header.get('FILENAME', ''))
    date_obs = header.get('DATE-OBS', 'Unknown Time')  # 観測時間を取得
    ax.set_title(f"Time: {date_obs}", fontsize=12)  # タイトルに観測時間を表示
    ax.set_xlabel("X [Solar Radius $R_\\odot$]", fontsize=10)
    ax.set_ylabel("Y [Solar Radius $R_\\odot$]", fontsize=10)

    return im

# フォルダー内のFITSファイルを取得
folder_path = "/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data"
fts_files = sorted(glob.glob(os.path.join(folder_path, "*.fts")))

# アニメーション作成
fig, ax = plt.subplots(figsize=(8, 8))

def update_frame(i):
    """アニメーションフレームを更新."""
    data, header = read_fits_file(fts_files[i])
    return [draw_frame(data, header, ax)]

ani = FuncAnimation(
    fig,
    update_frame,
    frames=len(fts_files),
    interval=15000 / len(fts_files),  # 15秒間隔に調整
)

# 動画の保存
output_path = "/home/kinno-7010/Document/Iwai2020event/kcor_animation.mp4"
ani.save(output_path, writer='ffmpeg', fps=10)

print(f"Animation saved to {output_path}")
# Out:
# Animation saved to /home/kinno-7010/Document/Iwai2020event/kcor_animation.mp4

# %%
# 2. 最初のFITSファイルを読み込む
if fts_files:
    data, header = read_fits_file(fts_files[0])

    # 3. 統計情報の計算
    stats = calculate_statistics(data)
    print(f"Statistics:", stats)
    print("fts_files[0]:", fts_files[0])

    # 4. 可視化
    visualize_fits_data(data, header, stats)
# Out:
# Statistics: {'min': np.float32(2.9689975e-14), 'max': np.float32(9.1430127e-07), 'mean': np.float32(5.6226565e-08), 'median': np.float32(1.2109165e-08), 'std': np.float32(1.0516418e-07)}
# fts_files[0]: /home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613_030011_kcor_l2.fts

# %% [markdown]
# ### memo

# %%
import tarfile

file_path = '/home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data/20220613.kcor_nrgf.fits.tar'

# アーカイブ内容を確認
with tarfile.open(file_path, 'r') as tar:
    print("Files in the archive:")
    for member in tar.getmembers():
        print(member.name)
# Out:
# Files in the archive:
# 20220613_030011_kcor_l2_nrgf.fts.gz
# 20220613_030027_kcor_l2_nrgf.fts.gz
# 20220613_030042_kcor_l2_nrgf.fts.gz
# 20220613_030057_kcor_l2_nrgf.fts.gz
# 20220613_030112_kcor_l2_nrgf.fts.gz
# 20220613_030127_kcor_l2_nrgf.fts.gz
# 20220613_030142_kcor_l2_nrgf.fts.gz
# 20220613_030158_kcor_l2_nrgf.fts.gz
# 20220613_030213_kcor_l2_nrgf.fts.gz
# 20220613_030228_kcor_l2_nrgf.fts.gz
# 20220613_030243_kcor_l2_nrgf.fts.gz
# 20220613_030258_kcor_l2_nrgf.fts.gz
# 20220613_030313_kcor_l2_nrgf.fts.gz
# 20220613_030329_kcor_l2_nrgf.fts.gz
# 20220613_030344_kcor_l2_nrgf.fts.gz
# 20220613_030359_kcor_l2_nrgf.fts.gz
# 20220613_030414_kcor_l2_nrgf.fts.gz
# 20220613_030429_kcor_l2_nrgf.fts.gz
# 20220613_030445_kcor_l2_nrgf.fts.gz
# 20220613_030500_kcor_l2_nrgf.fts.gz
# 20220613_030515_kcor_l2_nrgf.fts.gz
# 20220613_030530_kcor_l2_nrgf.fts.gz
# 20220613_030545_kcor_l2_nrgf.fts.gz
# 20220613_030600_kcor_l2_nrgf.fts.gz
# 20220613_030616_kcor_l2_nrgf.fts.gz
# 20220613_030631_kcor_l2_nrgf.fts.gz
# 20220613_030646_kcor_l2_nrgf.fts.gz
# 20220613_030701_kcor_l2_nrgf.fts.gz
# 20220613_030716_kcor_l2_nrgf.fts.gz
# 20220613_030731_kcor_l2_nrgf.fts.gz
# 20220613_030747_kcor_l2_nrgf.fts.gz
# 20220613_030802_kcor_l2_nrgf.fts.gz
# 20220613_030817_kcor_l2_nrgf.fts.gz
# 20220613_030832_kcor_l2_nrgf.fts.gz
# 20220613_030847_kcor_l2_nrgf.fts.gz
# 20220613_030902_kcor_l2_nrgf.fts.gz
# 20220613_030918_kcor_l2_nrgf.fts.gz
# 20220613_030933_kcor_l2_nrgf.fts.gz
# 20220613_030948_kcor_l2_nrgf.fts.gz
# 20220613_031003_kcor_l2_nrgf.fts.gz
# 20220613_031018_kcor_l2_nrgf.fts.gz
# 20220613_031033_kcor_l2_nrgf.fts.gz
# 20220613_031049_kcor_l2_nrgf.fts.gz
# 20220613_031104_kcor_l2_nrgf.fts.gz
# 20220613_031119_kcor_l2_nrgf.fts.gz
# 20220613_031134_kcor_l2_nrgf.fts.gz
# 20220613_031149_kcor_l2_nrgf.fts.gz
# 20220613_031204_kcor_l2_nrgf.fts.gz
# 20220613_031220_kcor_l2_nrgf.fts.gz
# 20220613_031235_kcor_l2_nrgf.fts.gz
# 20220613_031250_kcor_l2_nrgf.fts.gz
# 20220613_031305_kcor_l2_nrgf.fts.gz
# 20220613_031320_kcor_l2_nrgf.fts.gz
# 20220613_031336_kcor_l2_nrgf.fts.gz
# 20220613_031351_kcor_l2_nrgf.fts.gz
# 20220613_031406_kcor_l2_nrgf.fts.gz
# 20220613_031421_kcor_l2_nrgf.fts.gz
# 20220613_031436_kcor_l2_nrgf.fts.gz
# 20220613_031451_kcor_l2_nrgf.fts.gz
# 20220613_031507_kcor_l2_nrgf.fts.gz
# 20220613_031522_kcor_l2_nrgf.fts.gz
# 20220613_031537_kcor_l2_nrgf.fts.gz
# 20220613_031552_kcor_l2_nrgf.fts.gz
# 20220613_031607_kcor_l2_nrgf.fts.gz
# 20220613_031622_kcor_l2_nrgf.fts.gz
# 20220613_031638_kcor_l2_nrgf.fts.gz
# 20220613_031653_kcor_l2_nrgf.fts.gz
# 20220613_031708_kcor_l2_nrgf.fts.gz
# 20220613_031723_kcor_l2_nrgf.fts.gz
# 20220613_031738_kcor_l2_nrgf.fts.gz
# 20220613_031753_kcor_l2_nrgf.fts.gz
# 20220613_031809_kcor_l2_nrgf.fts.gz
# 20220613_031824_kcor_l2_nrgf.fts.gz
# 20220613_031839_kcor_l2_nrgf.fts.gz
# 20220613_031854_kcor_l2_nrgf.fts.gz
# 20220613_031909_kcor_l2_nrgf.fts.gz
# 20220613_031924_kcor_l2_nrgf.fts.gz
# 20220613_031940_kcor_l2_nrgf.fts.gz
# 20220613_031955_kcor_l2_nrgf.fts.gz
# 20220613_032010_kcor_l2_nrgf.fts.gz
# 20220613_032025_kcor_l2_nrgf.fts.gz
# 20220613_032040_kcor_l2_nrgf.fts.gz
# 20220613_032055_kcor_l2_nrgf.fts.gz
# 20220613_032111_kcor_l2_nrgf.fts.gz
# 20220613_032126_kcor_l2_nrgf.fts.gz
# 20220613_032141_kcor_l2_nrgf.fts.gz
# 20220613_032156_kcor_l2_nrgf.fts.gz
# 20220613_032211_kcor_l2_nrgf.fts.gz
# 20220613_032227_kcor_l2_nrgf.fts.gz
# 20220613_032242_kcor_l2_nrgf.fts.gz
# 20220613_032257_kcor_l2_nrgf.fts.gz
# 20220613_032312_kcor_l2_nrgf.fts.gz
# 20220613_032327_kcor_l2_nrgf.fts.gz
# 20220613_032342_kcor_l2_nrgf.fts.gz
# 20220613_032358_kcor_l2_nrgf.fts.gz
# 20220613_032413_kcor_l2_nrgf.fts.gz
# 20220613_032428_kcor_l2_nrgf.fts.gz
# 20220613_032443_kcor_l2_nrgf.fts.gz
# 20220613_032458_kcor_l2_nrgf.fts.gz
# 20220613_032513_kcor_l2_nrgf.fts.gz
# 20220613_032529_kcor_l2_nrgf.fts.gz
# 20220613_032544_kcor_l2_nrgf.fts.gz
# 20220613_032559_kcor_l2_nrgf.fts.gz
# 20220613_032614_kcor_l2_nrgf.fts.gz
# 20220613_032629_kcor_l2_nrgf.fts.gz
# 20220613_032644_kcor_l2_nrgf.fts.gz
# 20220613_032700_kcor_l2_nrgf.fts.gz
# 20220613_032715_kcor_l2_nrgf.fts.gz
# 20220613_032730_kcor_l2_nrgf.fts.gz
# 20220613_032745_kcor_l2_nrgf.fts.gz
# 20220613_032800_kcor_l2_nrgf.fts.gz
# 20220613_032815_kcor_l2_nrgf.fts.gz
# 20220613_032831_kcor_l2_nrgf.fts.gz
# 20220613_032846_kcor_l2_nrgf.fts.gz
# 20220613_032901_kcor_l2_nrgf.fts.gz
# 20220613_032916_kcor_l2_nrgf.fts.gz
# 20220613_032931_kcor_l2_nrgf.fts.gz
# 20220613_032946_kcor_l2_nrgf.fts.gz
# 20220613_033002_kcor_l2_nrgf.fts.gz
# 20220613_033017_kcor_l2_nrgf.fts.gz
# 20220613_033032_kcor_l2_nrgf.fts.gz
# 20220613_033047_kcor_l2_nrgf.fts.gz
# 20220613_033102_kcor_l2_nrgf.fts.gz
# 20220613_033117_kcor_l2_nrgf.fts.gz
# 20220613_033133_kcor_l2_nrgf.fts.gz
# 20220613_033148_kcor_l2_nrgf.fts.gz
# 20220613_033203_kcor_l2_nrgf.fts.gz
# 20220613_033218_kcor_l2_nrgf.fts.gz
# 20220613_033233_kcor_l2_nrgf.fts.gz
# 20220613_033249_kcor_l2_nrgf.fts.gz
# 20220613_033304_kcor_l2_nrgf.fts.gz
# 20220613_033319_kcor_l2_nrgf.fts.gz
# 20220613_033334_kcor_l2_nrgf.fts.gz
# 20220613_033349_kcor_l2_nrgf.fts.gz
# 20220613_033404_kcor_l2_nrgf.fts.gz
# 20220613_033420_kcor_l2_nrgf.fts.gz
# 20220613_033435_kcor_l2_nrgf.fts.gz
# 20220613_033450_kcor_l2_nrgf.fts.gz
# 20220613_033505_kcor_l2_nrgf.fts.gz
# 20220613_033520_kcor_l2_nrgf.fts.gz
# 20220613_033535_kcor_l2_nrgf.fts.gz
# 20220613_033551_kcor_l2_nrgf.fts.gz
# 20220613_033606_kcor_l2_nrgf.fts.gz
# 20220613_033621_kcor_l2_nrgf.fts.gz
# 20220613_033636_kcor_l2_nrgf.fts.gz
# 20220613_033651_kcor_l2_nrgf.fts.gz
# 20220613_033706_kcor_l2_nrgf.fts.gz
# 20220613_033722_kcor_l2_nrgf.fts.gz
# 20220613_033737_kcor_l2_nrgf.fts.gz
# 20220613_033752_kcor_l2_nrgf.fts.gz
# 20220613_033807_kcor_l2_nrgf.fts.gz
# 20220613_033822_kcor_l2_nrgf.fts.gz
# 20220613_033837_kcor_l2_nrgf.fts.gz
# 20220613_033853_kcor_l2_nrgf.fts.gz
# 20220613_033908_kcor_l2_nrgf.fts.gz
# 20220613_033923_kcor_l2_nrgf.fts.gz
# 20220613_033938_kcor_l2_nrgf.fts.gz
# 20220613_033953_kcor_l2_nrgf.fts.gz
# 20220613_034008_kcor_l2_nrgf.fts.gz
# 20220613_034024_kcor_l2_nrgf.fts.gz
# 20220613_034039_kcor_l2_nrgf.fts.gz
# 20220613_034054_kcor_l2_nrgf.fts.gz
# 20220613_034109_kcor_l2_nrgf.fts.gz
# 20220613_034124_kcor_l2_nrgf.fts.gz
# 20220613_034140_kcor_l2_nrgf.fts.gz
# 20220613_034155_kcor_l2_nrgf.fts.gz
# 20220613_034210_kcor_l2_nrgf.fts.gz
# 20220613_034225_kcor_l2_nrgf.fts.gz
# 20220613_034240_kcor_l2_nrgf.fts.gz
# 20220613_034255_kcor_l2_nrgf.fts.gz
# 20220613_034311_kcor_l2_nrgf.fts.gz
# 20220613_034326_kcor_l2_nrgf.fts.gz
# 20220613_034341_kcor_l2_nrgf.fts.gz
# 20220613_034356_kcor_l2_nrgf.fts.gz
# 20220613_034411_kcor_l2_nrgf.fts.gz
# 20220613_034426_kcor_l2_nrgf.fts.gz
# 20220613_034442_kcor_l2_nrgf.fts.gz
# 20220613_034457_kcor_l2_nrgf.fts.gz
# 20220613_034512_kcor_l2_nrgf.fts.gz
# 20220613_034527_kcor_l2_nrgf.fts.gz
# 20220613_034542_kcor_l2_nrgf.fts.gz
# 20220613_034557_kcor_l2_nrgf.fts.gz
# 20220613_034613_kcor_l2_nrgf.fts.gz
# 20220613_034628_kcor_l2_nrgf.fts.gz
# 20220613_034643_kcor_l2_nrgf.fts.gz
# 20220613_034658_kcor_l2_nrgf.fts.gz
# 20220613_034713_kcor_l2_nrgf.fts.gz
# 20220613_034728_kcor_l2_nrgf.fts.gz
# 20220613_034744_kcor_l2_nrgf.fts.gz
# 20220613_034759_kcor_l2_nrgf.fts.gz
# 20220613_034814_kcor_l2_nrgf.fts.gz
# 20220613_034829_kcor_l2_nrgf.fts.gz
# 20220613_034844_kcor_l2_nrgf.fts.gz
# 20220613_034859_kcor_l2_nrgf.fts.gz
# 20220613_034915_kcor_l2_nrgf.fts.gz
# 20220613_034930_kcor_l2_nrgf.fts.gz
# 20220613_034945_kcor_l2_nrgf.fts.gz
# 20220613_035000_kcor_l2_nrgf.fts.gz
# 20220613_035015_kcor_l2_nrgf.fts.gz
# 20220613_035030_kcor_l2_nrgf.fts.gz
# 20220613_035046_kcor_l2_nrgf.fts.gz
# 20220613_035101_kcor_l2_nrgf.fts.gz
# 20220613_035116_kcor_l2_nrgf.fts.gz
# 20220613_035131_kcor_l2_nrgf.fts.gz
# 20220613_035146_kcor_l2_nrgf.fts.gz
# 20220613_035202_kcor_l2_nrgf.fts.gz
# 20220613_035217_kcor_l2_nrgf.fts.gz
# 20220613_035232_kcor_l2_nrgf.fts.gz
# 20220613_035247_kcor_l2_nrgf.fts.gz
# 20220613_035302_kcor_l2_nrgf.fts.gz
# 20220613_035317_kcor_l2_nrgf.fts.gz
# 20220613_035333_kcor_l2_nrgf.fts.gz
# 20220613_035348_kcor_l2_nrgf.fts.gz
# 20220613_035403_kcor_l2_nrgf.fts.gz
# 20220613_035418_kcor_l2_nrgf.fts.gz
# 20220613_035433_kcor_l2_nrgf.fts.gz
# 20220613_035448_kcor_l2_nrgf.fts.gz
# 20220613_035504_kcor_l2_nrgf.fts.gz
# 20220613_035519_kcor_l2_nrgf.fts.gz
# 20220613_035534_kcor_l2_nrgf.fts.gz
# 20220613_035549_kcor_l2_nrgf.fts.gz
# 20220613_035604_kcor_l2_nrgf.fts.gz
# 20220613_035619_kcor_l2_nrgf.fts.gz
# 20220613_035635_kcor_l2_nrgf.fts.gz
# 20220613_035650_kcor_l2_nrgf.fts.gz
# 20220613_035705_kcor_l2_nrgf.fts.gz
# 20220613_035720_kcor_l2_nrgf.fts.gz
# 20220613_035735_kcor_l2_nrgf.fts.gz
# 20220613_035750_kcor_l2_nrgf.fts.gz
# 20220613_035806_kcor_l2_nrgf.fts.gz
# 20220613_035821_kcor_l2_nrgf.fts.gz
# 20220613_035836_kcor_l2_nrgf.fts.gz
# 20220613_035851_kcor_l2_nrgf.fts.gz
# 20220613_035906_kcor_l2_nrgf.fts.gz
# 20220613_035921_kcor_l2_nrgf.fts.gz
# 20220613_035937_kcor_l2_nrgf.fts.gz
# 20220613_035952_kcor_l2_nrgf.fts.gz
# README_DATAUSE_MLSO.txt

# %%
import os

# サブディレクトリを含む全ファイルを探索
fits_files = []
for root, dirs, files in os.walk(extract_folder):
    for file in files:
        if file.endswith('.fits'):
            fits_files.append(os.path.join(root, file))

print("Found FITS files:", fits_files)
# Out:
# Found FITS files: []

# %%
fits_files = []
for root, dirs, files in os.walk(extract_folder):
    for file in files:
        if file.endswith(('.fits', '.fit', '.fts')):
            fits_files.append(os.path.join(root, file))

print("Found FITS files:", fits_files)
# Out:
# Found FITS files: []

# %%
import tarfile

try:
    with tarfile.open(file_path, 'r') as tar:
        tar.extractall(path=extract_folder)
        print(f"Files successfully extracted to: {extract_folder}")
except Exception as e:
    print(f"Error during extraction: {e}")
# Out:
# Files successfully extracted to: /home/kinno-7010/Document/Iwai2020event/FITS file/K-COR data/White Light Level-2 Pb Data
