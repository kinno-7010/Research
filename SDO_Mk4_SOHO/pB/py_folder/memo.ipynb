# %%
from astropy.io import fits

pb_path = "D:wsl\home\kinno-7010\Research\SDO_Mk4_SOHO\pB\Rawdata/pB_Kcor_LASCO_axi_20220613_0300.fits"

with fits.open(pb_path, mode="update") as hdul:
    hdr = hdul[0].header
    # K-CORヘッダの値に置き換えてください（例）
    hdr["RSUN_OBS"] = 944.95  # arcsec
    hdr.add_history("Added RSUN_OBS (arcsec) for tomography normalization.")
    hdul.flush()
